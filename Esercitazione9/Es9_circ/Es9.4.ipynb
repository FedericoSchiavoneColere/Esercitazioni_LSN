# %%
import matplotlib.pyplot as plt

# Read the data file
with open('dati/dati.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_10.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_20.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_40.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_50.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_70.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_80.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_90.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]


# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_249.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')

plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/Dati_mig.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis('equal')
plt.grid(True)
plt.show()
