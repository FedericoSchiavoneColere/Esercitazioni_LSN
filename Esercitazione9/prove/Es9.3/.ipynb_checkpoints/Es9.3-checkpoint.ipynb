# %%
import matplotlib.pyplot as plt

# Read the data file
with open('dati.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_1.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_2.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_3.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_4.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_5.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_10.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_15.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_20.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati_29.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
