# %%
# direct: CALL and PUT

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

N = 100
x = np.arange(N)+1      # uso l'ordinamento da 1 a N

fig=plt.figure(figsize=(17,6))
plt.suptitle("Option pricing - campionamento diretto", fontsize = 25)

plt.subplot(1,2,1)
aveC, errC = np.loadtxt("direct.out", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x, aveC, yerr = errC)
plt.ylabel('Call option price', fontsize = 15)
plt.xlabel('Block number', fontsize = 15)
plt.grid(True)
plt.axhline(y=14.98, color = 'r', linestyle = '-', label = "Risultato analitico\n14.976")
plt.legend()

plt.subplot(1,2,2)
aveP, errP = np.loadtxt("direct.out", usecols=(2,3), delimiter=' ', unpack='true')
plt.errorbar(x, aveP, yerr = errP)
plt.ylabel('Put option price', fontsize = 15)
plt.xlabel('Block number', fontsize = 15)
plt.grid(True)
plt.axhline(y=5.46, color = 'r', linestyle = '-', label = "Risultato analitico\n5.4595")
plt.legend()

plt.show()

print('Risultato finale Call: ')
print(aveC[-1])
print('Incertezza statistica : ')
print(errC[-1])

print('\nRisultato finale Put: ')
print(aveP[-1])
print('Incertezza statistica : ')
print(errP[-1])
# Out:
# Risultato finale Call:
# 14.9995
# Incertezza statistica :
# 0.195186
#
# Risultato finale Put:
# 5.53332
# Incertezza statistica :
# 0.107744

# %%
#discretized: CALL and PUT

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

N = 100
x = np.arange(N)+1      # uso l'ordinamento da 1 a N

fig=plt.figure(figsize=(17,6))
plt.suptitle("Option pricing - campionamento discreto", fontsize = 25)

plt.subplot(1,2,1)
aveC, errC = np.loadtxt("discretized.out", usecols=(0,1), delimiter=' ', unpack='true')
plt.errorbar(x, aveC, yerr = errC)
plt.ylabel('Call option price', fontsize = 15)
plt.xlabel('Block number', fontsize = 15)
plt.grid(True)
plt.axhline(y=14.98, color = 'r', linestyle = '-',label = "Risultato analitico\n14.976")
plt.legend()

plt.subplot(1,2,2)
aveP, errP = np.loadtxt("discretized.out", usecols=(2,3), delimiter=' ', unpack='true')
plt.errorbar(x, aveP, yerr = errP)
plt.ylabel('Put option price', fontsize = 15)
plt.xlabel('Block number', fontsize = 15)
plt.grid(True)
plt.axhline(y=5.46, color = 'r', linestyle = '-', label = "Risultato analitico\n5.4595")
plt.legend()

plt.show()

print('Risultato finale Call: ')
print(aveC[-1])
print('Incertezza statistica : ')
print(errC[-1])

print('\nRisultato finale Put: ')
print(aveP[-1])
print('Incertezza statistica : ')
print(errP[-1])
# Out:
# Risultato finale Call:
# 14.9363
# Incertezza statistica :
# 0.195193
#
# Risultato finale Put:
# 5.34078
# Incertezza statistica :
# 0.0835451
