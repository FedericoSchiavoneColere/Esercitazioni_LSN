# %%
import matplotlib.pyplot as plt

# Read the data file
with open('dati/dati.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_10.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_20.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_40.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_50.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_70.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_80.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_0_90.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]


# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_2_499.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Read the data file
# ----> 2 with open('dati/dati_2_499.txt', 'r') as file:
#       3     lines = file.readlines()
#       5 # Extract the Cartesian points
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pygplates/lib/python3.9/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dati/dati_2_499.txt'

# %%
# Read the data file
with open('dati/Dati_Best.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
