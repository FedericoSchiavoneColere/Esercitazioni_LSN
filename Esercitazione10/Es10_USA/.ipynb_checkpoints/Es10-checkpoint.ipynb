# %%
import matplotlib.pyplot as plt

# Read the data file
with open('list.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_10.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_20.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_40.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_50.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_70.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_1_80.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_0_90.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]


# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/dati_2_499.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates
x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %%
# Read the data file
with open('dati/Dati_Best.txt', 'r') as file:
    lines = file.readlines()

# Extract the Cartesian points
points = []
for line in lines:
    x, y = line.strip().split()
    points.append((float(x), float(y)))

# Separate x and y coordinates

x = [point[0] for point in points]
y = [point[1] for point in points]

# Plot the points
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.title("Cartesian Points")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()
