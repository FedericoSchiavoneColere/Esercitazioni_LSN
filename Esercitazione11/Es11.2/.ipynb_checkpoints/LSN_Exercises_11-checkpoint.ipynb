# %% [markdown]
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.

# %%
# target parameters of f(x)

a=3
b=-2
c=-3
d=4

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = a* x_valid**3+b*x_valid**2+c*x_valid+d # ideal (target) linear function

sigma = 0.3 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a* x_train**3+b*x_train**2+c*x_train+d, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(a* x_valid**3+b*x_valid**2+c*x_valid+d, sigma)

# %%
# plot validation and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target, label='target')
plt.scatter(x_valid, y_valid, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()

model.add(Dense(2, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 2)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 16/16 [==============================] - 0s 3ms/step - loss: 10.1930 - mse: 10.1930 - val_loss: 9.1449 - val_mse: 9.1449
# Epoch 2/30
# 16/16 [==============================] - 0s 1ms/step - loss: 7.5693 - mse: 7.5693 - val_loss: 6.8922 - val_mse: 6.8922
# Epoch 3/30
# 16/16 [==============================] - 0s 1ms/step - loss: 5.6621 - mse: 5.6621 - val_loss: 5.2655 - val_mse: 5.2655
# Epoch 4/30
# 16/16 [==============================] - 0s 1ms/step - loss: 4.2904 - mse: 4.2904 - val_loss: 4.0775 - val_mse: 4.0775
# Epoch 5/30
# 16/16 [==============================] - 0s 1ms/step - loss: 3.2921 - mse: 3.2921 - val_loss: 3.2128 - val_mse: 3.2128
# Epoch 6/30
# 16/16 [==============================] - 0s 1ms/step - loss: 2.5690 - mse: 2.5690 - val_loss: 2.5800 - val_mse: 2.5800
# Epoch 7/30
# 16/16 [==============================] - 0s 1ms/step - loss: 2.0433 - mse: 2.0433 - val_loss: 2.1201 - val_mse: 2.1201
# Epoch 8/30
# 16/16 [==============================] - 0s 1ms/step - loss: 1.6631 - mse: 1.6631 - val_loss: 1.7810 - val_mse: 1.7810
# Epoch 9/30
# 16/16 [==============================] - 0s 1ms/step - loss: 1.3854 - mse: 1.3854 - val_loss: 1.5367 - val_mse: 1.5367
# Epoch 10/30
# 16/16 [==============================] - 0s 1ms/step - loss: 1.1865 - mse: 1.1865 - val_loss: 1.3561 - val_mse: 1.3561
# Epoch 11/30
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0411 - mse: 1.0411 - val_loss: 1.2243 - val_mse: 1.2243
# Epoch 12/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.9358 - mse: 0.9358 - val_loss: 1.1266 - val_mse: 1.1266
# Epoch 13/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8592 - mse: 0.8592 - val_loss: 1.0551 - val_mse: 1.0551
# Epoch 14/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.8040 - mse: 0.8040 - val_loss: 1.0014 - val_mse: 1.0014
# Epoch 15/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7628 - mse: 0.7628 - val_loss: 0.9618 - val_mse: 0.9618
# Epoch 16/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7333 - mse: 0.7333 - val_loss: 0.9326 - val_mse: 0.9326
# Epoch 17/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.7120 - mse: 0.7120 - val_loss: 0.9112 - val_mse: 0.9112
# Epoch 18/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6965 - mse: 0.6965 - val_loss: 0.8958 - val_mse: 0.8958
# Epoch 19/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6856 - mse: 0.6856 - val_loss: 0.8836 - val_mse: 0.8836
# Epoch 20/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6772 - mse: 0.6772 - val_loss: 0.8747 - val_mse: 0.8747
# Epoch 21/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6713 - mse: 0.6713 - val_loss: 0.8680 - val_mse: 0.8680
# Epoch 22/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6671 - mse: 0.6671 - val_loss: 0.8630 - val_mse: 0.8630
# Epoch 23/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6639 - mse: 0.6639 - val_loss: 0.8592 - val_mse: 0.8592
# Epoch 24/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6615 - mse: 0.6615 - val_loss: 0.8561 - val_mse: 0.8561
# Epoch 25/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6598 - mse: 0.6598 - val_loss: 0.8539 - val_mse: 0.8539
# Epoch 26/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6587 - mse: 0.6587 - val_loss: 0.8524 - val_mse: 0.8524
# Epoch 27/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6579 - mse: 0.6579 - val_loss: 0.8515 - val_mse: 0.8515
# Epoch 28/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6574 - mse: 0.6574 - val_loss: 0.8507 - val_mse: 0.8507
# Epoch 29/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6568 - mse: 0.6568 - val_loss: 0.8501 - val_mse: 0.8501
# Epoch 30/30
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6564 - mse: 0.6564 - val_loss: 0.8497 - val_mse: 0.8497

# %% [markdown]
# By looking at weights and biases we can see if the linear fit was successfull: $w_1$ represents the angular coefficient, $b$ the intercept.

# %%
# return weights and biases
model.get_weights()
# Out:
# [array([[-1.1623617, -1.1458979]], dtype=float32),
#  array([3.2897453, 3.289895 ], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8497 - mse: 0.8497
#
# Test loss: 0.8497267961502075
# Test accuracy: 0.8497267961502075

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8278 - mse: 0.8278
#
# Test loss: 0.8277533650398254
# Test accuracy: 0.8277533650398254

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, (100, 1))
y_predicted = model.predict(x_predicted)

x_predicted = np.squeeze(x_predicted)
y_predicted = np.squeeze(y_predicted)

plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 4
#       2 y_predicted = model.predict(x_predicted)
#       3 y_predicted = np.squeeze(y_predicted)
# ----> 4 plt.scatter(x_predicted, y_predicted,color='r')
#       5 plt.plot(x_valid, y_target)
#       6 plt.grid(True)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pygplates/lib/python3.9/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pygplates/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/pygplates/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4584, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582 y = np.ma.ravel(y)
#    4583 if x.size != y.size:
# -> 4584     raise ValueError("x and y must be the same size")
#    4586 if s is None:
#    4587     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4588          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>
